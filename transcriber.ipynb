# %%
# --- SET YOUR INPUT PATH HERE ---
# This can be a path to a single file OR a folder containing multiple audio files
# INPUT_PATH = r"c:\Users\Sakib\Downloads\WhatsApp Audio 2025-10-07 at 10.53.41.mpeg"

INPUT_PATH = r"F:\OneDrive - Green Energy\Sakib\ogg to transcription\ogg"

# %%
# Audio to Text Transcription with Groq
import os
import time
import shutil
import subprocess
from pathlib import Path
from groq import Groq
from dotenv import load_dotenv

# Install required packages (run once)
# !pip install python-dotenv groq pydub

# --- Configuration ---
load_dotenv()
GROQ_API_KEY = os.getenv("GROQ_API_KEY")
OUTPUT_FOLDER = os.getenv("OUTPUT_FOLDER", "transcriptions")

# List of common audio/video extensions that can be processed
SUPPORTED_EXTENSIONS = {'.mp3', '.mpeg', '.mp4', '.wav', '.m4a', '.flac', '.ogg', '.aac', '.webm'}


def check_ffmpeg():
    """Check if FFmpeg is installed"""
    try:
        subprocess.run(['ffmpeg', '-version'], capture_output=True, check=True)
        print("✓ FFmpeg is available")
        return True
    except (subprocess.CalledProcessError, FileNotFoundError):
        print("❌ FFmpeg not found. Please install FFmpeg:")
        print("- Windows: Download from https://ffmpeg.org/download.html")
        print("- macOS: brew install ffmpeg")
        print("- Linux: sudo apt install ffmpeg")
        return False

def convert_to_mp3(input_file, output_file):
    """Convert audio/video file to MP3 using FFmpeg"""
    try:
        cmd = [
            'ffmpeg',
            '-i', str(input_file),
            '-vn',                 # Skip video if present (saves space)
            '-codec:a', 'libmp3lame',
            '-b:a', '192k',
            '-y',                  # Overwrite output file if it exists
            str(output_file)
        ]
        
        subprocess.run(cmd, capture_output=True, text=True, check=True)
        print(f"✓ Converted: {input_file.name} -> {output_file.name}")
        return True
    except subprocess.CalledProcessError as e:
        print(f"❌ Error converting {input_file.name}: {e.stderr}")
        return False

def transcribe_audio(audio_file_path, groq_client, max_retries=5):
    """Transcribe audio file using Groq API with Retry Logic"""
    
    base_wait_time = 5 # Start with a 5 second wait

    for attempt in range(max_retries):
        try:
            with open(audio_file_path, "rb") as file:
                transcription = groq_client.audio.transcriptions.create(
                    file=(audio_file_path.name, file.read()),
                    model="whisper-large-v3",
                    response_format="text"
                )
            return transcription
        except Exception as e:
            error_msg = str(e).lower()
            # If we haven't reached the max retries, wait and try again
            if attempt < max_retries - 1:
                wait_time = base_wait_time * (2 ** attempt)  # 5s, 10s, 20s, 40s...
                print(f"⚠️ API Error: {str(e)}")
                print(f"⏳ Retrying in {wait_time} seconds... (Attempt {attempt + 2} of {max_retries})")
                time.sleep(wait_time)
            else:
                print(f"❌ Failed to transcribe {audio_file_path.name} after {max_retries} attempts.")
                print(f"Final Error: {str(e)}")
                return None

def process_single_audio_file(input_path, output_path, groq_client):
    """Processes a single file: converts to mp3, transcribes, and saves output."""
    print("-" * 50)
    print(f"Processing: {input_path.name}")

    # Define the path for the converted MP3 file
    mp3_file = output_path / f"{input_path.stem}.mp3"
    
    # Check if file is already MP3 and copy it to the output folder
    if input_path.suffix.lower() == '.mp3':
        shutil.copy(input_path, mp3_file)
        print(f"✓ Already MP3. Copied to output folder: {mp3_file.name}")
    else:
        # Convert to MP3 if necessary
        if not convert_to_mp3(input_path, mp3_file):
            return

    # Transcribe the MP3 file
    print(f"🎤 Transcribing: {mp3_file.name}")
    transcription = transcribe_audio(mp3_file, groq_client)

    if transcription:
        print(f"✓ Transcription completed for: {input_path.name}")
        
        # Save transcription to text file
        txt_file = output_path / f"{input_path.stem}_transcription.txt"
        with open(txt_file, 'w', encoding='utf-8') as f:
            f.write(transcription)
        print(f"✓ Saved transcription to: {txt_file}")
        
        print(f"Snippet: {transcription[:150]}...") # Print a small snippet instead of the whole file
    else:
        print("❌ Transcription failed.")

def process_input(input_path_str, output_folder, groq_api_key):
    """Main function to handle paths (both files and directories)"""
    
    input_path = Path(input_path_str)
    
    if not input_path.exists():
        print(f"❌ Input path not found: '{input_path}'")
        return

    # 1. Gather all files to process
    files_to_process = []
    
    if input_path.is_file():
        if input_path.suffix.lower() in SUPPORTED_EXTENSIONS:
            files_to_process.append(input_path)
        else:
            print(f"❌ Unsupported file extension: {input_path.suffix}")
            return
            
    elif input_path.is_dir():
        print(f"📁 Directory detected. Scanning for audio files...")
        for f in input_path.iterdir():
            if f.is_file() and f.suffix.lower() in SUPPORTED_EXTENSIONS:
                files_to_process.append(f)
                
        if not files_to_process:
            print(f"❌ No supported audio files found in directory: {input_path}")
            return
            
    print(f"Found {len(files_to_process)} file(s) to process.")

    # 2. Check dependencies and initialize clients once
    if not check_ffmpeg():
        return

    try:
        groq_client = Groq(api_key=groq_api_key)
        print("✓ Groq client initialized")
    except Exception as e:
        print(f"❌ Error initializing Groq client: {str(e)}")
        return

    # 3. Ensure output directory exists
    output_path = Path(output_folder)
    output_path.mkdir(exist_ok=True)

    # 4. Process each file
    for idx, file_path in enumerate(files_to_process, start=1):
        print(f"\n[{idx}/{len(files_to_process)}]")
        process_single_audio_file(file_path, output_path, groq_client)

    print("\n🎉 All processing complete!")

# Run the main processing function
if __name__ == "__main__":
    # Validate configuration
    if not GROQ_API_KEY or GROQ_API_KEY == "your_groq_api_key_here":
        print("⚠️ Please set your Groq API key in the .env file (GROQ_API_KEY='your_key')")
    elif not INPUT_PATH or INPUT_PATH == "path/to/your/audio_file_or_folder":
        print("⚠️ Please set the path to your audio file or folder in the INPUT_PATH variable.")
    else:
        # Process the specified audio path
        process_input(INPUT_PATH, OUTPUT_FOLDER, GROQ_API_KEY)
# Out:
# 📁 Directory detected. Scanning for audio files...
# Found 11 file(s) to process.
# ✓ FFmpeg is available
# ✓ Groq client initialized
#
# [1/11]
# --------------------------------------------------
# Processing: 1 (1).ogg
# ✓ Converted: 1 (1).ogg -> 1 (1).mp3
# 🎤 Transcribing: 1 (1).mp3
# ✓ Transcription completed for: 1 (1).ogg
# ✓ Saved transcription to: transcriptions\1 (1)_transcription.txt
# Snippet:  Hi there Saqib. So I was testing the agent. Here's a couple issues. First of all, let's talk about fundamentals. Fundamentals is that this phone call...
#
# [2/11]
# --------------------------------------------------
# Processing: 1 (10).ogg
# ✓ Converted: 1 (10).ogg -> 1 (10).mp3
# 🎤 Transcribing: 1 (10).mp3
# ✓ Transcription completed for: 1 (10).ogg
# ✓ Saved transcription to: transcriptions\1 (10)_transcription.txt
# Snippet:  um again this is i'm running a business and this is very important for me for this to work 24 hours all the time with no mistakes so i can't just cal...
# ...
